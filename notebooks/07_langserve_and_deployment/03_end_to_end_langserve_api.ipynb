# %% [markdown]
# <div dir="rtl">
#
# # 🚀 03 - End-to-End LangServe Deployment Pipeline
#
# ## ما هو هذا الكراس؟
# هذا هو الكراس الختامي لمسار **النشر والمخرجات المهيكلة**. يوضح معمارية الخدمة الكاملة من البداية وحتى اختبار استدعاء الخادم المحلي برمجيًا.
#
# </div>

# %% [markdown]
# ### 1️⃣ تهيئة وتجهيز المكونات

# %%
import os
from pathlib import Path
from dotenv import load_dotenv, find_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langserve import RemoteRunnable

load_dotenv(find_dotenv())
print("✅ البيئة جاهزة لمسار النشر الشامل.")

# %% [markdown]
# ### 2️⃣ اختبار الاتصال بـ RemoteRunnable (عميل الاتصال)

# %%
# يتيح RemoteRunnable التفاعل مع أي خادم LangServe بعيد أو محلي وكأنه سلسلة محلية
remote_url = "http://localhost:8000/chain"

print(f"🔗 عميل الاتصال جاهز للاستدعاء عبر: {remote_url}")
print("ملاحظة: يمكنك تشغيل الخادم عبر فتح التيرمنال وتشغيل: uv run python notebooks/07_langserve_and_deployment/serve.py")

# %% [markdown]
# <div dir="rtl">
#
# ## 🏁 الخلاصة:
# تم استكمال مسار نشر النماذج كـ Microservices تفاعلية بنجاح. يمكنك الآن دمج أي سلسلة LCEL مع خادم FastAPI محلي وتوصيلها بأي واجهة تطبيق مستخدم.
#
# </div>
